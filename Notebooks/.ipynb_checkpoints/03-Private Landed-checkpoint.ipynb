# %% [markdown]
# # C-Value - Private Landed Property
# The next bound:
#
# 1. Combine multiple data sources:
#     1. HDB information from [Data.gov.sg](https://data.gov.sg/dataset/hdb-property-information)
#     2. Condo information from www.data.com.sg (also scrape this)
#     3. Square Foot API
# 2. Time Series

# %%
# Import required modules
import dns_property as dns
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import warnings

from numpy.random import seed
from lightgbm import LGBMRegressor
from os import listdir
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import RepeatedKFold, train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Settings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Data

# %%
# Read data
df = pd.read_csv('../Data/caveat_data_final.csv')
df = df[df.category=='Landed']

# Preview
df.head()
# Out:
#        sn                project_name         street_name           type  \
# 55422   1  LANDED HOUSING DEVELOPMENT       FABER HEIGHTS  Semi-detached
# 55423   2  LANDED HOUSING DEVELOPMENT  PASIR PANJANG ROAD  Semi-detached
# 55424   3  LANDED HOUSING DEVELOPMENT  PASIR PANJANG ROAD        Terrace
# 55425   4                 FABER HILLS         FABER GREEN        Terrace
# 55426   5  LANDED HOUSING DEVELOPMENT         OCEAN DRIVE        Terrace
#
#        postal_district market_segment                             tenure  \
# 55422                5            OCR                           Freehold
# 55423                5            RCR                           Freehold
# 55424                5            RCR                           Freehold
# 55425                5            OCR                           Freehold
# 55426                4            CCR  99 yrs lease commencing from 2004
#
#       type_of_sale  no_of_units      price  ... area_sqft  type_of_area  \
# 55422       Resale          1.0  5150000.0  ...    4053.0          Land
# 55423       Resale          1.0  2718000.0  ...    2530.0          Land
# 55424       Resale          1.0  3100000.0  ...    1886.0          Land
# 55425       Resale          1.0  3025000.0  ...    2102.0          Land
# 55426       Resale          1.0  5700000.0  ...    3316.0          Land
#
#       floor_level  target  date_of_sale category remaining_lease  freehold  \
# 55422           -  1271.0      Aug-2019   Landed            9999         1
# 55423           -  1075.0      Jul-2019   Landed            9999         1
# 55424           -  1644.0      Jul-2019   Landed            9999         1
# 55425           -  1439.0      Jul-2019   Landed            9999         1
# 55426           -  1719.0      Jun-2019   Landed              84         0
#
#        age  floor
# 55422   34    1.0
# 55423   34    1.0
# 55424   34    1.0
# 55425   34    1.0
# 55426   15    1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# Create month
df['mth'] = pd.to_datetime(df['date_of_sale'])

# %%
# # Generate month lags
# for var in ['type', 'market_segment', 'postal_district', 'street_name', 'project_name', 'freehold']:

#     df = dns.fe_mth(df, var, 1)
#     df = dns.fe_qtr(df, var, 1)

# %%
df.columns
# Out:
# Index(['sn', 'project_name', 'street_name', 'type', 'postal_district',
#        'market_segment', 'tenure', 'type_of_sale', 'no_of_units', 'price',
#        'nett_price', 'area_sqft', 'type_of_area', 'floor_level', 'target',
#        'date_of_sale', 'category', 'remaining_lease', 'freehold', 'age',
#        'floor', 'mth'],
#       dtype='object')

# %%
df.head()
# Out:
#        sn                project_name         street_name           type  \
# 55422   1  LANDED HOUSING DEVELOPMENT       FABER HEIGHTS  Semi-detached
# 55423   2  LANDED HOUSING DEVELOPMENT  PASIR PANJANG ROAD  Semi-detached
# 55424   3  LANDED HOUSING DEVELOPMENT  PASIR PANJANG ROAD        Terrace
# 55425   4                 FABER HILLS         FABER GREEN        Terrace
# 55426   5  LANDED HOUSING DEVELOPMENT         OCEAN DRIVE        Terrace
#
#        postal_district market_segment                             tenure  \
# 55422                5            OCR                           Freehold
# 55423                5            RCR                           Freehold
# 55424                5            RCR                           Freehold
# 55425                5            OCR                           Freehold
# 55426                4            CCR  99 yrs lease commencing from 2004
#
#       type_of_sale  no_of_units      price  ... type_of_area  floor_level  \
# 55422       Resale          1.0  5150000.0  ...         Land            -
# 55423       Resale          1.0  2718000.0  ...         Land            -
# 55424       Resale          1.0  3100000.0  ...         Land            -
# 55425       Resale          1.0  3025000.0  ...         Land            -
# 55426       Resale          1.0  5700000.0  ...         Land            -
#
#        target date_of_sale  category remaining_lease freehold  age  floor  \
# 55422  1271.0     Aug-2019    Landed            9999        1   34    1.0
# 55423  1075.0     Jul-2019    Landed            9999        1   34    1.0
# 55424  1644.0     Jul-2019    Landed            9999        1   34    1.0
# 55425  1439.0     Jul-2019    Landed            9999        1   34    1.0
# 55426  1719.0     Jun-2019    Landed              84        0   15    1.0
#
#              mth
# 55422 2019-08-01
# 55423 2019-07-01
# 55424 2019-07-01
# 55425 2019-07-01
# 55426 2019-06-01
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Conventional CV

# %%
# Private Vars
drop_vars_pri = ['sn', 'tenure', 'no_of_units', 'price', 'nett_price', 'floor_level', 'target', 'date_of_sale', 'category', 'mth']
vars_pri_bin = ['type', 'type_of_sale', 'type_of_area', 'market_segment', 'postal_district']

# Configure data
X_data = pd.get_dummies(df.drop(drop_vars_pri, axis=1),
                        columns=vars_pri_bin)
y_data = df['target']

# Configure CV
cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=100)

# Configure stop words
stop_words = [
    'road', 'avenue', 'street', 'drive', 'lorong', 'crescent', 'view', 'rise'
    'jalan', 'lane', 'walk', 'link', 'bukit',
    'rd', 'ave', 'st', 'dr', 'lor', 'cres', 'jln', 'pl'
]

# %% [markdown]
# ### K-NN

# %%
kn = KNeighborsRegressor(n_neighbors=10, weights='distance', n_jobs=4)
kn_cv = dns.custom_cv(kn, X_data, y_data, cv, ['project_name', 'street_name'], stop_words, norm=True, ppd=True)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 5...
# Running iteration 2 of 5...
# Running iteration 3 of 5...
# Running iteration 4 of 5...
# Running iteration 5 of 5...
#
# [MODEL STATISTICS]
# M-PPD: 8.33%
# PPD Deviation:
#   +-5.0%: 35.66%
#   +-10%: 55.52%
#   +-20%: 78.38%
#
# MAPE: 13.95%
# MAE: $160
# RMSE: $248
# R2: 67.34%

# %% [markdown]
# ### LightGBM

# %%
lg = LGBMRegressor(n_estimators=1000, num_leaves=50, max_depth=10, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
lg_cv = dns.custom_cv(lg, X_data, y_data, cv, ['project_name', 'street_name'], stop_words, ppd=True)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 5...
# Running iteration 2 of 5...
# Running iteration 3 of 5...
# Running iteration 4 of 5...
# Running iteration 5 of 5...
#
# [MODEL STATISTICS]
# M-PPD: 7.81%
# PPD Deviation:
#   +-5.0%: 34.96%
#   +-10%: 58.46%
#   +-20%: 82.74%
#
# MAPE: 11.98%
# MAE: $141
# RMSE: $217
# R2: 74.86%

# %% [markdown]
# ## Step-Forward Testing

# %%
# Private Vars
drop_vars_pri = ['sn', 'tenure', 'no_of_units', 'price', 'nett_price', 'floor_level', 'target', 'date_of_sale', 'category']
vars_pri_bin = ['type', 'type_of_sale', 'type_of_area', 'market_segment', 'postal_district']

# Configure data
X_data = pd.get_dummies(df.drop(drop_vars_pri, axis=1),
                        columns=vars_pri_bin)
y_data = df['target']

# Configure CV
cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=100)

# Initialise models
lg = LGBMRegressor(n_estimators=1000, num_leaves=50, max_depth=10, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
kn = KNeighborsRegressor(n_neighbors=10, weights='distance', n_jobs=4)

# Configure stop words
stop_words = [
    'road', 'avenue', 'street', 'drive', 'lorong', 'crescent', 'view', 'rise'
    'jalan', 'lane', 'walk', 'link', 'bukit',
    'rd', 'ave', 'st', 'dr', 'lor', 'cres', 'jln', 'pl'
]

# %% [markdown]
# ### K-NN

# %%
kn = KNeighborsRegressor(n_neighbors=10, weights='distance', n_jobs=4)
kn_cv = dns.custom_ts(rgr=kn, X=X_data, y=y_data, timevar='mth', start='2018-09-01', tfidf_cols=['project_name', 'street_name'], stop_words=stop_words, dropout=0.1, ppd=True, random_state=100)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 12...
# Running iteration 2 of 12...
# Running iteration 3 of 12...
# Running iteration 4 of 12...
# Running iteration 5 of 12...
# Running iteration 6 of 12...
# Running iteration 7 of 12...
# Running iteration 8 of 12...
# Running iteration 9 of 12...
# Running iteration 10 of 12...
# Running iteration 11 of 12...
# Running iteration 12 of 12...
# [MODEL STATISTICS]
# M-PPD: 14.07%
# PPD Deviation:
#   +-5.0%: 25.94%
#   +-10%: 41.38%
#   +-20%: 61.58%
#
# MAPE: 22.35%
# MAE: $236
# RMSE: $336
# R2: 39.03%

# %% [markdown]
# ### LightGBM

# %%
lg = LGBMRegressor(n_estimators=1000, num_leaves=50, max_depth=10, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
lg_cv = dns.custom_ts(rgr=lg, X=X_data, y=y_data, timevar='mth', start='2018-09-01', tfidf_cols=['project_name', 'street_name'], stop_words=stop_words, dropout=0.1, ppd=True, random_state=100)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 12...
# Running iteration 2 of 12...
# Running iteration 3 of 12...
# Running iteration 4 of 12...
# Running iteration 5 of 12...
# Running iteration 6 of 12...
# Running iteration 7 of 12...
# Running iteration 8 of 12...
# Running iteration 9 of 12...
# Running iteration 10 of 12...
# Running iteration 11 of 12...
# Running iteration 12 of 12...
# [MODEL STATISTICS]
# M-PPD: 8.38%
# PPD Deviation:
#   +-5.0%: 32.97%
#   +-10%: 56.86%
#   +-20%: 82.30%
#
# MAPE: 11.40%
# MAE: $142
# RMSE: $206
# R2: 76.44%

# %% [markdown]
# ## Step-Forward Testing with FE

# %%
# Private Vars
drop_vars_pri = ['sn', 'tenure', 'no_of_units', 'price', 'nett_price', 'floor_level', 'target', 'date_of_sale', 'category', 'mth_l', 'qtr', 'qtr_l']
vars_pri_bin = ['type', 'type_of_sale', 'type_of_area', 'market_segment', 'postal_district']

# Copy data
df2 = df.copy()

# Generate month lags
for var in ['type', 'market_segment', 'postal_district', 'street_name', 'project_name', 'freehold']:

    df2 = dns.fe_mth(df2, var, 1)
    df2 = dns.fe_qtr(df2, var, 1)

# Configure data
X_data = pd.get_dummies(df2.drop(drop_vars_pri, axis=1),
                        columns=vars_pri_bin)
y_data = df2['target']

# Configure CV
cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=100)

# Configure stop words
stop_words = [
    'road', 'avenue', 'street', 'drive', 'lorong', 'crescent', 'view', 'rise'
    'jalan', 'lane', 'walk', 'link', 'bukit',
    'rd', 'ave', 'st', 'dr', 'lor', 'cres', 'jln', 'pl'
]

# %% [markdown]
# ### K-NN

# %%
kn = KNeighborsRegressor(n_neighbors=10, weights='distance', n_jobs=4)
kn_cv = dns.custom_ts(rgr=kn, X=X_data, y=y_data, timevar='mth', start='2018-09-01', tfidf_cols=['project_name', 'street_name'], stop_words=stop_words, dropout=0.1, ppd=True, random_state=100)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 12...
# Running iteration 2 of 12...
# Running iteration 3 of 12...
# Running iteration 4 of 12...
# Running iteration 5 of 12...
# Running iteration 6 of 12...
# Running iteration 7 of 12...
# Running iteration 8 of 12...
# Running iteration 9 of 12...
# Running iteration 10 of 12...
# Running iteration 11 of 12...
# Running iteration 12 of 12...
# [MODEL STATISTICS]
# M-PPD: 13.23%
# PPD Deviation:
#   +-5.0%: 22.33%
#   +-10%: 39.86%
#   +-20%: 66.28%
#
# MAPE: 19.69%
# MAE: $211
# RMSE: $298
# R2: 52.12%

# %% [markdown]
# ### LightGBM

# %%
lg = LGBMRegressor(n_estimators=1000, num_leaves=50, max_depth=10, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
lg_cv = dns.custom_ts(rgr=lg, X=X_data, y=y_data, timevar='mth', start='2018-09-01', tfidf_cols=['project_name', 'street_name'], stop_words=stop_words, dropout=0.1, ppd=True, random_state=100)
# Out:
# # ---- COMPUTING C-VALUE ---- #
# Running iteration 1 of 12...
# Running iteration 2 of 12...
# Running iteration 3 of 12...
# Running iteration 4 of 12...
# Running iteration 5 of 12...
# Running iteration 6 of 12...
# Running iteration 7 of 12...
# Running iteration 8 of 12...
# Running iteration 9 of 12...
# Running iteration 10 of 12...
# Running iteration 11 of 12...
# Running iteration 12 of 12...
# [MODEL STATISTICS]
# M-PPD: 9.29%
# PPD Deviation:
#   +-5.0%: 29.47%
#   +-10%: 53.28%
#   +-20%: 79.54%
#
# MAPE: 13.03%
# MAE: $155
# RMSE: $221
# R2: 72.77%
